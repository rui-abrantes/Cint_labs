# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from operator import index

import seaborn as sns

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# # Loading the IRIS dataset

# %%
iris_df = pd.read_csv('./iris/iris.data')
bezdekiris_df = pd.read_csv('./iris/bezdekIris.data')

# %%
iris_df.plot()

# %%
bezdekiris_df.plot()

# %% [markdown]
# # Data Visualization

# %%
sns.relplot(data=iris_df, x="S_Width", y="P_Lenght", hue="Output", style="P_Width")

# %%
sns.relplot(data=iris_df, x="S_Width", y="S_Lenght", hue="Output", style="P_Width")

# %%
sns.relplot(data=iris_df, x="S_Lenght", y="P_Lenght", hue="Output", style="P_Width")

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
Rand = iris_df.to_numpy()
y = iris_df['Output'].to_numpy()
X = np.delete(Rand, np.s_[-1:], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
gnb = GaussianNB()

# %%
y_pred = gnb.fit(X_train, y_train).predict(X_test)

print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 45 points : 0

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
precision_score(y_test, y_pred, average="weighted")
# Out:
# 1.0

# %%
recall_score(y_test, y_pred, average="weighted")
# Out:
# 1.0

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 18,  0],
#        [ 0,  0, 11]])
